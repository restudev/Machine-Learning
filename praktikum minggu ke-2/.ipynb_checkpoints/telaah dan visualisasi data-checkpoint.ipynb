# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "laptops.csv"
df = pd.read_csv(path)

# %%
# menampilkan 10 baris awal dari dataset 
df.head(10)
# Out:
#    index    brand                                              Model  Price  \
# 0      1    tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2    tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3       hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3      4     acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5   lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# 5      6    apple  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...  70990
# 6      7  infinix  Infinix INBook Y2 Plus Laptop (11th Gen Core i...  34990
# 7      8     asus  Asus TUF Gaming F15 FX506HF-HN024W Gaming Lapt...  49990
# 8      9       hp  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  36990
# 9     10  infinix  Infinix Zerobook 2023 Laptop (13th Gen Core i9...  59990
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd        ryzen 5          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
# 5      45           apple             m1          8            8           8
# 6      56           intel        core i5          4            8          16
# 7      70           intel        core i5          6           12           8
# 8      60           intel        core i3          6            8           8
# 9      71           intel        core i9         14           20          32
#
#    ... secondary_storage_type  secondary_storage_capacity gpu_brand  \
# 0  ...   No secondary storage                           0     intel
# 1  ...   No secondary storage                           0     intel
# 2  ...   No secondary storage                           0       amd
# 3  ...   No secondary storage                           0     intel
# 4  ...   No secondary storage                           0       amd
# 5  ...   No secondary storage                           0     apple
# 6  ...   No secondary storage                           0     intel
# 7  ...   No secondary storage                           0    nvidia
# 8  ...   No secondary storage                           0     intel
# 9  ...   No secondary storage                           0     intel
#
#      gpu_type is_touch_screen display_size  resolution_width  \
# 0  integrated           False         15.6              1920
# 1  integrated           False         15.6              1920
# 2   dedicated           False         15.6              1920
# 3  integrated           False         14.0              1920
# 4  integrated           False         15.6              1920
# 5       apple           False         13.3              2560
# 6  integrated           False         15.6              1920
# 7   dedicated           False         15.6              1920
# 8  integrated           False         15.6              1920
# 9  integrated           False         15.6              1920
#
#    resolution_height       OS  year_of_warranty
# 0               1080  windows                 1
# 1               1080  windows                 1
# 2               1080  windows                 1
# 3               1080  windows                 1
# 4               1080  windows                 1
# 5               1600      mac                 1
# 6               1080  windows                 1
# 7               1080  windows                 1
# 8               1080  windows                 1
# 9               1080  windows                 1
#
# [10 rows x 22 columns]

# %%
# menampilkan 10 baris akhir dari dataset
df.tail(10)

# %%
# mengungkap tipe-tipe data dari setiap kolom
print(df.dtypes)

# %%
df.count()

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)

# %%
#  mencari jumlah nilai-nilai yang hilang (NaN/null) dalam setiap kolom dataframe
print(df.isnull().sum())

# %%
df = df.dropna() # menghapus nilai yang hilang
df.count()

# %%
df = df.iloc[:,2:]
df

# %%
# menampilkan statistik dasar setiap kolom data yang bertipe numerik.
df_noid.describe()

# %%
# jika ingin menampilkan juga statistik kolom- 
# yang bertipe non-numerik, mencakup beberapa banyak nilai unik- 
# dalam kolom (unique), nilai modus(top), serta frekuensi modus(freq)
df_noid.describe(include="all")

# %%
kolom_numerik = df.select_dtypes(include='number')

# %%
mean = kolom_numerik.mean()
mean
# Out:
# Price                         77266.504541
# Rating                           63.931382
# num_cores                         8.128153
# num_threads                      12.191726
# ram_memory                       13.047427
# primary_storage_capacity        610.938446
# secondary_storage_capacity        4.004036
# display_size                     15.171241
# resolution_width               2003.503532
# resolution_height              1181.227043
# dtype: float64

# %%
sum = kolom_numerik.sum()
sum
# Out:
# Price                         76571106.0
# Rating                           63356.0
# num_cores                         8055.0
# num_threads                      12082.0
# ram_memory                       12930.0
# primary_storage_capacity        605440.0
# secondary_storage_capacity        3968.0
# display_size                     15034.7
# resolution_width               1985472.0
# resolution_height              1170596.0
# dtype: float64

# %%
median = kolom_numerik.median()
median
# Out:
# Price                         61900.0
# Rating                           64.0
# num_cores                         8.0
# num_threads                      12.0
# ram_memory                       16.0
# primary_storage_capacity        512.0
# secondary_storage_capacity        0.0
# display_size                     15.6
# resolution_width               1920.0
# resolution_height              1080.0
# dtype: float64

# %%
varians = kolom_numerik.var()
varians
# Out:
# Price                         3.293028e+09
# Rating                        1.038478e+02
# num_cores                     1.777043e+01
# num_threads                   3.119351e+01
# ram_memory                    3.126138e+01
# primary_storage_capacity      7.125038e+04
# secondary_storage_capacity    1.125867e+03
# display_size                  8.800105e-01
# resolution_width              1.310189e+05
# resolution_height             6.963478e+04
# dtype: float64

# %%
# menghitung standar deviasi dari setiap kolom 
deviasi = kolom_numerik.std()
deviasi
# Out:
# Price                         57384.910269
# Rating                           10.190575
# num_cores                         4.215499
# num_threads                       5.585115
# ram_memory                        5.591188
# primary_storage_capacity        266.927666
# secondary_storage_capacity       33.553936
# display_size                      0.938089
# resolution_width                361.965292
# resolution_height               263.884019
# dtype: float64

# %%
# menghitung kuantil ke-75 dari setiap kolom
kuantil = kolom_numerik.quantile(0.75)
kuantil
# Out:
# Price                         89245.0
# Rating                           71.0
# num_cores                        10.0
# num_threads                      16.0
# ram_memory                       16.0
# primary_storage_capacity        512.0
# secondary_storage_capacity        0.0
# display_size                     15.6
# resolution_width               1920.0
# resolution_height              1200.0
# Name: 0.75, dtype: float64

# %%
# membulatkan setiap elemen dalam dataframe df_noid
df_noid.round(2).mode()

# %%
q1 = kolom_numerik.quantile(0.25)
q3 = kolom_numerik.quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# Price                         45650.0
# Rating                           13.0
# num_cores                         4.0
# num_threads                       8.0
# ram_memory                        8.0
# primary_storage_capacity          0.0
# secondary_storage_capacity        0.0
# display_size                      1.6
# resolution_width                  0.0
# resolution_height               120.0
# dtype: float64

# %%
# handle warning 
import warnings 
warnings.filterwarnings('ignore')

# outlier filter
df_noid_align, iqr_new = kolom_numerik.align(iqr, axis=1, copy=False, join='outer')
outlier_filter = (kolom_numerik < q1 - 1.5 * iqr_new) | (kolom_numerik > q3 + 1.5 * iqr_new)
outlier_filter

# %%
df_noid[outlier_filter['Rating']] \
    .loc[:, ['Model', 'Rating']] \
    .sort_values(by=['Rating'], ascending=False)

# %%
df_noid['processor_brand'].value_counts()

# %%
brand1 = df[df['brand'] == 'lenovo']
brand1
# Out:
#      index   brand                                              Model   Price  \
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...   28580
# 14      15  lenovo  Lenovo IdeaPad Slim 3 82H803LKIN Laptop (11th ...   47490
# 16      17  lenovo  Lenovo V15 G3 IAP 82TTA08AIN Laptop (12th Gen ...   49990
# 21      22  lenovo  Lenovo V15 G4 82YU00W7IN Laptop (AMD Ryzen 3 7...   27990
# 32      34  lenovo  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...   47990
# ..     ...     ...                                                ...     ...
# 948    960  lenovo  Lenovo Thinkpad P16s 21BTS02000 Laptop (12th G...  146271
# 950    962  lenovo  Lenovo ThinkBook 14 20VDA0V1IH Laptop (11th Ge...   43500
# 954    966  lenovo  Lenovo V14 82KAA08BIH Laptop (11th Gen Core i3...   30990
# 956    968  lenovo  Lenovo V15 G3 82TTA01EIN Laptop (12th Gen Core...   32200
# 960    972  lenovo  Lenovo Thinkbook 15 21DJA0D9IH Laptop (12th Ge...   59990
#
#      Rating processor_brand processor_tier  num_cores  num_threads  \
# 4        62             amd        ryzen 3          4            8
# 14       66           intel        core i5          4            8
# 16       59           intel        core i7         10           12
# 21       59             amd        ryzen 3          4            8
# 32       71           intel        core i5          4            8
# ..      ...             ...            ...        ...          ...
# 948      75           intel        core i7         12           16
# 950      54           intel        core i3          2            4
# 954      50           intel        core i3          2            4
# 956      48           intel        core i3          6            8
# 960      64           intel        core i5         10           12
#
#      ram_memory  ... secondary_storage_type  secondary_storage_capacity  \
# 4             8  ...   No secondary storage                           0
# 14           16  ...   No secondary storage                           0
# 16           16  ...   No secondary storage                           0
# 21            8  ...   No secondary storage                           0
# 32            8  ...   No secondary storage                           0
# ..          ...  ...                    ...                         ...
# 948          16  ...   No secondary storage                           0
# 950           8  ...   No secondary storage                           0
# 954           8  ...   No secondary storage                           0
# 956           8  ...   No secondary storage                           0
# 960          16  ...   No secondary storage                           0
#
#     gpu_brand    gpu_type is_touch_screen display_size  resolution_width  \
# 4         amd  integrated           False         15.6              1920
# 14      intel  integrated           False         15.6              1920
# 16      intel  integrated           False         15.6              1920
# 21        amd  integrated           False         15.6              1920
# 32     nvidia   dedicated           False         15.6              1920
# ..        ...         ...             ...          ...               ...
# 948    nvidia   dedicated           False         16.0              1920
# 950     intel  integrated           False         14.0              1920
# 954     intel  integrated           False         14.0              1920
# 956     intel  integrated           False         15.6              1920
# 960     intel  integrated           False         15.6              1920
#
#      resolution_height       OS  year_of_warranty
# 4                 1080  windows                 1
# 14                1080  windows                 1
# 16                1080  windows                 1
# 21                1080  windows                 1
# 32                1080  windows                 1
# ..                 ...      ...               ...
# 948               1200  windows                 3
# 950               1080      dos                 1
# 954               1080      dos                 1
# 956               1080      dos                 1
# 960               1080  windows                 1
#
# [201 rows x 22 columns]

# %%
brand2 = df[df['brand'] == 'apple']
brand2
# Out:
#      index  brand                                              Model   Price  \
# 5        6  apple  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...   70990
# 22      23  apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...  399900
# 34      36  apple  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...  102990
# 67      73  apple  Apple MacBook Air 15 2023 Laptop (Apple M2/ 8G...  119990
# 133    141  apple  Apple MacBook Pro 2022 Laptop (Apple M2/ 8GB/ ...  109990
# 141    152  apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Pro...  289900
# 142    153  apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...  349900
# 143    154  apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Pro...  249900
# 144    155  apple  Apple MacBook Pro 14 2023 Laptop (Apple M3 Pro...  199900
# 213    224  apple  Apple MacBook Air 15 2023 Laptop (Apple M2/ 8G...  144990
# 275    286  apple  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...  132990
# 276    287  apple  Apple MacBook Pro 2022 Laptop (Apple M2/ 8GB/ ...  136990
# 322    334  apple  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...  189900
# 323    335  apple  Apple MacBook Pro 14 2023 Laptop (Apple M3 Pro...  239900
# 332    344  apple  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...  169900
#
#      Rating processor_brand processor_tier  num_cores  num_threads  \
# 5        45           apple             m1          8            8
# 22       65           apple             m3         16           16
# 34       48           apple             m2          8            8
# 67       53           apple             m2          8            8
# 133      43           apple             m2          8            8
# 141      63           apple             m3         12           12
# 142      64           apple             m3         14           14
# 143      58           apple             m3         12           12
# 144      56           apple             m3         11           11
# 213      56           apple             m2          8            8
# 275      45           apple             m2          8            8
# 276      45           apple             m2          8            8
# 322      53           apple             m3          8            8
# 323      58           apple             m3         12           12
# 332      51           apple             m3          8            8
#
#      ram_memory  ... secondary_storage_type  secondary_storage_capacity  \
# 5             8  ...   No secondary storage                           0
# 22            8  ...   No secondary storage                           0
# 34            8  ...   No secondary storage                           0
# 67            8  ...   No secondary storage                           0
# 133           8  ...   No secondary storage                           0
# 141          36  ...   No secondary storage                           0
# 142          36  ...   No secondary storage                           0
# 143           8  ...   No secondary storage                           0
# 144           8  ...   No secondary storage                           0
# 213           8  ...   No secondary storage                           0
# 275           8  ...   No secondary storage                           0
# 276           8  ...   No secondary storage                           0
# 322           8  ...   No secondary storage                           0
# 323           8  ...   No secondary storage                           0
# 332           8  ...   No secondary storage                           0
#
#     gpu_brand  gpu_type is_touch_screen display_size  resolution_width  \
# 5       apple     apple           False         13.3              2560
# 22      apple     apple           False         16.2              3456
# 34      apple     apple           False         13.6              2560
# 67      apple     apple           False         15.3              2880
# 133     apple     apple           False         13.3              2560
# 141     apple     apple           False         16.2              3456
# 142     apple     apple           False         16.2              3456
# 143     apple     apple           False         16.2              3456
# 144     apple     apple           False         14.2              3024
# 213     apple     apple           False         15.3              2880
# 275     apple     apple           False         13.6              2560
# 276     apple     apple           False         13.3              2560
# 322     apple     apple           False         14.2              3024
# 323     apple     apple           False         14.2              3024
# 332     apple     apple           False         14.2              3024
#
#      resolution_height   OS  year_of_warranty
# 5                 1600  mac                 1
# 22                2234  mac                 1
# 34                1664  mac                 1
# 67                1864  mac                 1
# 133               1600  mac                 1
# 141               2234  mac                 1
# 142               2234  mac                 1
# 143               2234  mac                 1
# 144               1964  mac                 1
# 213               1864  mac                 1
# 275               1664  mac                 1
# 276               1600  mac                 1
# 322               1964  mac                 1
# 323               1964  mac                 1
# 332               1964  mac                 1
#
# [15 rows x 22 columns]

# %%
brandLenovo = brand1[brand1['ram_memory	'] > 8]
brandLenovo
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_memory\t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[337], line 1
# ----> 1 brandLenovo = brand1[brand1['ram_memory	'] >8]
#       2 brandLenovo
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ram_memory\t'
