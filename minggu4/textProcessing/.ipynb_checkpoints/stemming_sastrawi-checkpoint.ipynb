# %% [markdown]
# Stemming menggunakan Sastrawi
# =============================
#
# ***Restu Lestari Mulianingrum (A11.2022.14668)***

# %% [markdown]
# # load dataset

# %%
import pandas as pd

# %%
dataset = pd.read_csv('clean_dataset.csv', sep=';')

# %%
dataset.head()
# Out:
#    Unnamed: 0                                            content  sentimen  \
# 0           1                             Dana mmg keren mantap.  POSITIVE
# 1           2  Saya ngajuin upgrade dana premium krna ktp say...  NEGATIVE
# 2           3  Kocak mana diskon nya ml malah eror segala kag...  NEGATIVE
# 3           4  Saldo hilang karena no lama Hilang ganti no sa...  NEGATIVE
# 4           6  Udah gua hapus dana ya. ilang ya udah 1 juta l...  NEGATIVE
#
#                                               step01  \
# 0                              dana mmg keren mantap
# 1  saya ngajuin upgrade dana premium krna ktp say...
# 2  kocak mana diskon nya ml malah eror segala kag...
# 3  saldo hilang karena no lama hilang ganti no sa...
# 4  udah gua hapus dana ya ilang ya udah   juta le...
#
#                                               tokens  \
# 0                 ['dana', 'mmg', 'keren', 'mantap']
# 1  ['saya', 'ngajuin', 'upgrade', 'dana', 'premiu...
# 2  ['kocak', 'mana', 'diskon', 'nya', 'ml', 'mala...
# 3  ['saldo', 'hilang', 'karena', 'no', 'lama', 'h...
# 4  ['udah', 'gua', 'hapus', 'dana', 'ya', 'ilang'...
#
#                                         final_tokens  \
# 0                 ['dana', 'mmg', 'keren', 'mantap']
# 1  ['saya', 'ngajuin', 'upgrade', 'dana', 'premiu...
# 2  ['kocak', 'mana', 'diskon', 'nya', 'ml', 'mala...
# 3  ['saldo', 'hilang', 'karena', 'no', 'lama', 'h...
# 4  ['udah', 'gua', 'hapus', 'dana', 'ya', 'ilang'...
#
#                                               step02
# 0                              dana mmg keren mantap
# 1  saya ngajuin upgrade dana premium krna ktp say...
# 2  kocak mana diskon nya ml malah eror segala kag...
# 3  saldo hilang karena no lama hilang ganti no sa...
# 4  udah gua hapus dana ya ilang ya udah juta lebi...

# %% [markdown]
# # load sastrawi sebagai stemmer

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ## hapus stop words

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#        Unnamed: 0                                            content  \
# 0               1                             Dana mmg keren mantap.
# 1               2  Saya ngajuin upgrade dana premium krna ktp say...
# 2               3  Kocak mana diskon nya ml malah eror segala kag...
# 3               4  Saldo hilang karena no lama Hilang ganti no sa...
# 4               6  Udah gua hapus dana ya. ilang ya udah 1 juta l...
# ...           ...                                                ...
# 35432       49993  Amanah, biasanya kerja juga pake apk dana buat...
# 35433       49994  Kak tolong perbaiki dana saya, Karena tidak mu...
# 35434       49996                            error, tidak bisa masuk
# 35435       49997                                     Cukup membantu
# 35436       49998  tolong pihak dana knp saldo saya hilang,ada yg...
#
#        sentimen                                             step01  \
# 0      POSITIVE                              dana mmg keren mantap
# 1      NEGATIVE  saya ngajuin upgrade dana premium krna ktp say...
# 2      NEGATIVE  kocak mana diskon nya ml malah eror segala kag...
# 3      NEGATIVE  saldo hilang karena no lama hilang ganti no sa...
# 4      NEGATIVE  udah gua hapus dana ya ilang ya udah   juta le...
# ...         ...                                                ...
# 35432   NEUTRAL  amanah biasanya kerja juga pake apk dana buat ...
# 35433   NEUTRAL  kak tolong perbaiki dana saya karena tidak mun...
# 35434  NEGATIVE                             error tidak bisa masuk
# 35435  POSITIVE                                     cukup membantu
# 35436   NEUTRAL  tolong pihak dana knp saldo saya hilang ada yg...
#
#                                                   tokens  \
# 0                     ['dana', 'mmg', 'keren', 'mantap']
# 1      ['saya', 'ngajuin', 'upgrade', 'dana', 'premiu...
# 2      ['kocak', 'mana', 'diskon', 'nya', 'ml', 'mala...
# 3      ['saldo', 'hilang', 'karena', 'no', 'lama', 'h...
# 4      ['udah', 'gua', 'hapus', 'dana', 'ya', 'ilang'...
# ...                                                  ...
# 35432  ['amanah', 'biasanya', 'kerja', 'juga', 'pake'...
# 35433  ['kak', 'tolong', 'perbaiki', 'dana', 'saya', ...
# 35434                ['error', 'tidak', 'bisa', 'masuk']
# 35435                              ['cukup', 'membantu']
# 35436  ['tolong', 'pihak', 'dana', 'knp', 'saldo', 's...
#
#                                             final_tokens  \
# 0                     ['dana', 'mmg', 'keren', 'mantap']
# 1      ['saya', 'ngajuin', 'upgrade', 'dana', 'premiu...
# 2      ['kocak', 'mana', 'diskon', 'nya', 'ml', 'mala...
# 3      ['saldo', 'hilang', 'karena', 'no', 'lama', 'h...
# 4      ['udah', 'gua', 'hapus', 'dana', 'ya', 'ilang'...
# ...                                                  ...
# 35432  ['amanah', 'biasanya', 'kerja', 'juga', 'pake'...
# 35433  ['kak', 'tolong', 'perbaiki', 'dana', 'saya', ...
# 35434                ['error', 'tidak', 'bisa', 'masuk']
# 35435                              ['cukup', 'membantu']
# 35436  ['tolong', 'pihak', 'dana', 'knp', 'saldo', 's...
#
#                                                   step02  \
# 0                                  dana mmg keren mantap
# 1      saya ngajuin upgrade dana premium krna ktp say...
# 2      kocak mana diskon nya ml malah eror segala kag...
# 3      saldo hilang karena no lama hilang ganti no sa...
# 4      udah gua hapus dana ya ilang ya udah juta lebi...
# ...                                                  ...
# 35432  amanah biasanya kerja juga pake apk dana buat ...
# 35433  kak tolong perbaiki dana saya karena tidak mun...
# 35434                             error tidak bisa masuk
# 35435                                     cukup membantu
# 35436  tolong pihak dana knp saldo saya hilang ada yg...
#
#                                            finalText_str  \
# 0                                  dana mmg keren mantap
# 1      saya ngajuin upgrade dana premium krna ktp say...
# 2      kocak mana diskon nya ml malah eror segala kag...
# 3      saldo hilang karena no lama hilang ganti no sa...
# 4      udah gua hapus dana ya ilang ya udah juta lebi...
# ...                                                  ...
# 35432  amanah biasanya kerja juga pake apk dana buat ...
# 35433  kak tolong perbaiki dana saya karena tidak mun...
# 35434                             error tidak bisa masuk
# 35435                                     cukup membantu
# 35436  tolong pihak dana knp saldo saya hilang ada yg...
#
#                                            ProcessedText
# 0                                  dana mmg keren mantap
# 1      ngajuin upgrade dana premium krna ktp buram jd...
# 2      kocak mana diskon ml malah eror segala kaga ik...
# 3      saldo hilang no lama hilang ganti no saldo gk ...
# 4      udah gua hapus dana ilang udah juta lebih duwi...
# ...                                                  ...
# 35432  amanah biasa kerja pake apk dana buat ngisi ua...
# 35433          kak baik dana karena muncul dana paylater
# 35434                                   error bisa masuk
# 35435                                        cukup bantu
# 35436  pihak dana knp saldo hilang yg bobol akun gk m...
#
# [35437 rows x 9 columns]

# %%
dataset.to_csv('clean_dataset_stem.csv',sep=';')
